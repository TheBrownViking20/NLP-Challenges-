# %%
import numpy as np
import pandas as pd

import re
import fileinput
from nltk.tokenize import wordpunct_tokenize
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, make_pipeline

from sklearn.linear_model import PassiveAggressiveClassifier

# %%
corpus = open('corpus.txt', 'r', encoding='utf-8-sig').read()

# %%
begin_title = '\n{3,}\s+THE SECRET CACHE\n{3,}.*'
corpus = re.search(begin_title, corpus, flags=re.M+re.S).group()
corpus = corpus.replace('\n', ' ') 
corpus = re.sub(r' {2,}', ' ', corpus)
corpus = corpus.replace('----', '')

# %%
valid_forms = ['am','are','were','was','is','been','being','be']
blank = '----'

# %%
tokens = wordpunct_tokenize(corpus)

# %%
def detect(tokens):
    return [t for t in tokens if t in valid_forms]
    
def replace_blank(tokens):
    return [blank if t in valid_forms else t for t in tokens]

def create_windows(tokens, window_size=3):
    X = []
    for i, word in enumerate(tokens):
        if word == blank:
            window = tokens[i-window_size:i] + tokens[i+1:i+window_size+1]
            window = ' '.join(window)
            X.append(window)    
    return X

# %%
y = detect(tokens)
tokens = replace_blank(tokens)
X = create_windows(tokens)

# %%
X
# Out:
# ['water . It the first day',
#  '. Three canoes engaged in the',
#  'the nearest canoe a fine figure',
#  'the bank had holding his breath',
#  ', when he close enough to',
#  'close enough to heard above the',
#  'think it may so , since',
#  ', the boy running along the',
#  '. Monsieur Cadotte alone , going',
#  'Hugh Beaupré ” written in a',
#  'that the writing not his father',
#  '. The letter in French ,',
#  '. The handwriting good , better',
#  'not where he and the waves',
#  '. But he sore hurt in',
#  'that the furs for you and',
#  '. “ It bad news ?”',
#  '“ My father dead .” “',
#  '’ s voice vibrant with sympathy',
#  '. “ It not , I',
#  'No , he wrecked .” Hugh',
#  ', and he so sorely hurt',
#  '. If there anything I can',
#  'Montreal .” Hugh at a loss',
#  'though Cadotte had , Hugh dared',
#  'Jean Beaupré had a free trader',
#  'his father had in the habit',
#  'likely he had under some contract',
#  'the fur companies hot and bitter',
#  'bitter . Hugh very sure that',
#  'that the pelts destined for the',
#  '. The boy in a difficult',
#  'quickly . Cadotte eying him sharply',
#  '“ This letter from my half',
#  'lamely . Cadotte regarding Hugh keenly',
#  's embarrassed manner enough to make',
#  'suspect that Hugh not telling the',
#  '“ It may difficult to send',
#  '. If you an experienced canoeman',
#  ', but you not and ——”',
#  '. If I not sailor enough',
#  'see what can done ,” Cadotte',
#  'if matters can arranged .” II',
#  'him go to with his father',
#  'died when he less than a',
#  'years he had to Montreal to',
#  'the west had eagerly listened to',
#  'had begged to allowed to go',
#  'when Hugh would sixteen . Delayed',
#  'father had not seen at the',
#  'lake . There no chance for',
#  'strange packet he now carrying in',
#  'his elder son at the Sault',
#  '. But there no explanation of',
#  'there . Hugh grieved to learn',
#  '. Jean Beaupré almost a stranger',
#  '. Indeed he little more than',
#  'imagination . It scarcely possible that',
#  's grief could deep , and',
#  'for the time , it ----',
#  '---- , it overshadowed by other',
#  '. He had suddenly plunged ,',
#  'that there should such a person',
#  'The boy had brought up to',
#  'and that it his inconsolable grief',
#  'the letter must well grown ,',
#  'breed boy who to ---- his',
#  'who ---- to his comrade in',
#  'woods , that evident . Somewhere',
#  ', where he obliged to beat',
#  'curiosity . Hugh quite willing to',
#  'Baptiste , I in a difficulty',
#  'Kaministikwia . It my father ’',
#  'himself . We to divide the',
#  '.” “ There an inheritance then',
#  'them . It a long journey',
#  'of the dead a grievous sin',
#  '. How then I to find',
#  '. “ There the sloop _Otter_',
#  'think . There repairs to the',
#  ', but they finished . Then',
#  '. Then there new rigging and',
#  'It will not long until she',
#  'long until she ready .” That',
#  'whether the trader aware of the',
#  ', it would better to have',
#  'Point aux Pins short , but',
#  'in spring flood strenuous work ,',
#  'Signs of spring everywhere . The',
#  '. The snow gone , and',
#  ', migrating birds flitting and twittering',
#  'willows and alders beginning to unfold',
#  'Pine Point , the Northwest Company',
#  'to the company built and repaired',
#  'winter there , now anchored a',
#  'The repairs had completed and a',
#  'of white paint ---- applied to',
#  'white paint ---- applied to her',
#  'other refuse to thrown out ,',
#  '. Captain Bennett personally superintending the',
#  ', who had previously engaged as',
#  '. Lawrence ,” the boy ’',
#  'At least you a white man',
#  'rapids where she to receive her',
#  'Beaupré , had accepted as one',
#  'goods the sloop to transport had',
#  'to transport had received the preceding',
#  'too late to forwarded across Superior',
#  'Superior . They to ---- sent',
#  'They ---- to sent on now',
#  'Thunder Bay , expected at the',
#  'goods brought would transferred to the',
#  'the remainder would taken on in',
#  'canoes . Hugh heartily glad that',
#  'glad that he not obliged to',
#  'probability there would no vacant places',
#  'and if there any , he',
#  ', he would accepted . He',
#  '. The sloop of only seventy',
#  'time of loading a busy one',
#  '. The cargo varied : provisions',
#  'fine . It remarkably fine for',
#  'crew of six not heavy .',
#  'the Michipicoton River a Northwest Company',
#  'unloading , Hugh permitted to go',
#  'of the Indians arriving from the',
#  'smaller streams should free of ice',
#  '. The weather not so pleasant',
#  'for the sky overcast . In',
#  'In the air a bitter chill',
#  'strong enough to called a gale',
#  '’ s work far harder and',
#  'duties . There no good harbor',
#  ', the gale still from the',
#  'of location had lost . Under',
#  'ropes , he of little enough',
#  'shore nor sky to ---- seen',
#  'sky ---- to seen , only',
#  'no ice had encountered , but',
#  'as well have midnight . The',
#  'The weary crew fighting ceaselessly to',
#  'with ice , torn away .',
#  'down . He following the mast',
#  'loose the wreckage accomplished . The',
#  'preceding one , no less miserable',
#  'she seemed to back in midwinter',
#  'but the lake still so rough',
#  '. Two men kept constantly at',
#  '. No canvas left but the',
#  '. It had so long since',
#  'by land might . Shadowy as',
#  'its forbidding character plain enough ,',
#  '. So worn he from lack',
#  'forbidding though it , had revived',
#  'the wind , passing between forest',
#  'hand and ahead land . The',
#  '- limbed trees plainly visible .',
#  'though the _Otter_ , her strained',
#  'her strained seams leaking freely ,',
#  'for the time , Captain Bennett',
#  's next care for his crew',
#  'of a man a matter for',
#  'to Hugh , worn out ,',
#  'the bone had hasty and rough',
#  '. The point almost level and',
#  'the bud , wet , snow',
#  'and the clouds breaking . Around',
#  'The broken arm reset , the',
#  'the fire , set up .',
#  'lean - to completed the sun',
#  'completed the sun shining . In',
#  'snow and ice beginning to melt',
#  '- capped chickadees flitting about the',
#  'and white woodpecker hammering busily at',
#  '. No attempt made to repair',
#  'most necessary work done , and',
#  'the sheltered harbor a welcome haven',
#  'morning their tracks found in the',
#  'on the _Otter_ begun . The',
#  '. The water pumped out ,',
#  'the strained seams calked and a',
#  ', straight spruce felled and trimmed',
#  'time the weather bright , and',
#  'had taken refuge a real bay',
#  'discovered whether he on the mainland',
#  'to his ship of the first',
#  'until the _Otter_ made seaworthy once',
#  'human beings had found . The',
#  'or white , in the habit',
#  'day the sloop launched , anchored',
#  'While the reloading going on ,',
#  'which they rowed , at first',
#  'the land they skirting rose more',
#  ', his eyes on the water',
#  'water . He endeavoring to locate',
#  '. “ What it , Baptiste',
#  'Baptiste ? Where we ?” asked',
#  'eagerness that it not his place',
#  '. “ It Thunder Cape ,”',
#  'the New Fort situated .” “',
#  'Truly it must the Cap au',
#  'to the north the Cape at',
#  '.” “ We not as far',
#  ', sir , this land where',
#  'land where we ?” Captain Bennett',
#  '. “ We on an island',
#  'one . There only one island',
#  'island it can , the Isle',
#  'northwest breeze would almost dead against',
#  ', and it increasing . We',
#  'hand . They skirting a rock',
#  '“ someone has here before us',
#  '. “ There the end of',
#  'two found themselves tightly wedged in',
#  '. The bow smashed and splintered',
#  'Indeed the boat half full of',
#  'ice . It a crude looking',
#  'known paint , weathered and water',
#  '. The wreck quite empty ,',
#  'peculiarity which could seen even in',
#  'mast had stood painted bright red',
#  ', the paint evidently a mixture',
#  'grease . It but little faded',
#  'red background had drawn , in',
#  'if such paintings customary on the',
#  ', yes ,” the reply ,',
#  'the men who in her when',
#  'her when she driven on these',
#  '“ It may that no one',
#  'that no one in her .',
#  'not think anyone wrecked here .',
#  '. This bateau carried away in',
#  'shore . There nothing in her',
#  ', though she right side up',
#  'up when she driven in here',
#  ', there has no one to',
#  'here . It far to come',
#  'and I have told that the',
#  'They think it inhabited by spirits',
#  'Manitos . It said that in',
#  '“ If there copper on the',
#  'and — we not away from',
#  ', and had driven into the',
#  'of interest had found in the',
#  'night the reloading finished and everything',
#  'shore proved to a low ,',
#  'of the voyage made in good',
#  'great bay , the scarcely less',
#  'learned that it due to some',
#  'time the sloop well into Thunder',
#  'southeast . Clouds gathering and rain',
#  'The north channel the principal mouth',
#  'Kaministikwia , had the chief station',
#  'the Northwest Company a Canadian organization',
#  'the company headquarters removed to Canadian',
#  'on Thunder Bay built the New',
#  ', later to known as Fort',
#  's chief post bustling with activity',
#  'enclosure , had completed the year',
#  'within the walls still going on',
#  'and other buildings under construction or',
#  'the kilns that turning out bricks',
#  'and temporary , on hand to',
#  'eyes . It not so much',
#  'affairs that he thinking . Anxiously',
#  'front ranks , his half -',
#  'concluded that Blaise either not there',
#  'not there or waiting for him',
#  'that he might more closely questioned',
#  'Kaministikwia , and relieved to reach',
#  'wilderness surroundings , worth seeing ,',
#  'there . He keenly aware that',
#  'that his business likely to ----',
#  '---- likely to , not with',
#  'the New Fort low and swampy',
#  'land had not cleared for building',
#  ', the place not cheerful or',
#  '. The sky gray and lowering',
#  'river . He walking slowly ,',
#  'thoughts as to scarcely conscious of',
#  'shoulder . It a low ,',
#  'an intonation that not English .',
#  'sheathed knife that his only weapon',
#  'His dark features unmistakably Indian in',
#  'familiarity . They the eyes of',
#  'eyes that had the most notable',
#  '?” “ You my half -',
#  '“ My English bad , but',
#  '“ Let it French then ,',
#  '. “ I at school with',
#  'answered . Hugh surprised . This',
#  ', but he no mere wild',
#  '. “ I on the shore',
#  ', you must my brother ,',
#  '“ I have told that I',
#  '’ s manner still cool and',
#  'mean you have following me around',
#  'watched . It not difficult ,',
#  'an opening had made by the',
#  'fainting . It some time before',
#  'his weakness he determined to tell',
#  '. While he there , a',
#  'The winter had mild , with',
#  'but his speech vague and disconnected',
#  'the bateau had wrecked in a',
#  ', for he clearly aware that',
#  '. The pelts a very good',
#  '. But it the packet about',
#  'where his brother to ---- found',
#  'brother ---- to found , and',
#  'who happened to at the Grand',
#  'father , he much moved at',
#  'son , had unrightfully defrauded .',
#  'It will not an easy search',
#  'where the furs hidden ?” “',
#  'except that it a short way',
#  '.” “ That possible . I',
#  '. The boat driven on the',
#  'rocks . That all I know',
#  'think he must dead , or',
#  ', although he the younger by',
#  ', “ what it caused my',
#  'hardship ? Or he hurt when',
#  'when the boat wrecked ? You',
#  '.” “ It not starvation and',
#  '. “ He hurt , sore',
#  '“ Our father sore hurt ,',
#  '. The wound in his side',
#  '. The wound a knife wound',
#  'It might have in fair fight',
#  '. Our father ever quick with',
#  'bull moose himself not braver .',
#  'think the blow not a fair',
#  'I think it struck from behind',
#  'it must have . Could it',
#  'Could it have his companion who',
#  'he who struck not killed by',
#  'you and I left to avenge',
#  'father .” It plain that Christian',
#  's own feelings nearly as fierce',
#  'over , he free to go',
#  'the Fort should completed , with',
#  ', it would almost a village',
#  'Outside the stockade a shipyard and',
#  'of Montreal , less impressed with',
#  'unfinished , than the voyageur who',
#  'the trading post forced to ----',
#  '---- forced to a little city',
#  'the wigwams Blaise living , awaiting',
#  '. Hugh had able to bring',
#  'Now that he no longer a',
#  'he and Hugh going to get',
#  'the furs would successful , preferred',
#  'the quarrel had that Beaupré had',
#  'the two organizations fierce and ruthless',
#  'that “ all fair in love',
#  'relations between them very nearly those',
#  'Beaupré had probably the victim of',
#  'discovered that he carrying his furs',
#  '. Accordingly he inclined to believe',
#  'believe there might some foundation for',
#  'his father had murdered because of',
#  '“ That may ,” he replied',
#  '“ but it not in that',
#  '.” And that the only comment',
#  'his course and just where he',
#  'believed himself to . This feat',
#  'Before the day over , that',
#  'the older boy also the heavier',
#  'Wielding a paddle not a new',
#  'prove that he no green hand',
#  's . Hugh sturdy , well',
#  ', but it Blaise who set',
#  'of his body cramped and numb',
#  'just fourteen , nearly three years',
#  'him . It the weather that',
#  ', the day bright . The',
#  'of Thunder Bay smooth at first',
#  'back and shoulders strained , it',
#  '“ Shall we delayed long ,',
#  '“ It may that the wind',
#  ', if we to stay here',
#  'weight evenly , securely tied to',
#  'the iron kettle swung over the',
#  'when the stew ready , Hugh',
#  '. If Blaise weary he had',
#  'The open lake now rich blue',
#  'The May wind bitterly cold ,',
#  '. The ground so hard the',
#  'poles could not driven in .',
#  'down , it either frozen or',
#  '. The boys obliged to brace',
#  'he woke he pleased to find',
#  'Perhaps the latter wearier than he',
#  'Both blankets would needed for bedding',
#  'so the screen taken down and',
#  'supply of wood gathered and balsam',
#  'soon as he rolled in his',
#  ', but Hugh wakeful . He',
#  '. The morning clear and the',
#  'minutes of paddling difficult and painful',
#  'unfavorable weather must frequent and unavoidable',
#  'Hugh and Blaise lucky during the',
#  'Bay . Hugh gaining experience and',
#  'his paddling muscles hardening . He',
#  'He would soon able , he',
#  'and grave to sure , but',
#  'boy decided , , in spite',
#  'seemed , Hugh in no haste',
#  'first meeting had entirely peaceful but',
#  'yet , Hugh obliged to admit',
#  'of their companionship to come .',
#  'begun , but to begin soon',
#  'soon . It into his wife',
#  'bateau must have wrecked and the',
#  'among the trees deserted . Of',
#  'bark covering had stripped , and',
#  'canoe , it strange we did',
#  '? The ashes wet with rain',
#  'ago or has out many days',
#  'days . There another message here',
#  'the bark had peeled off and',
#  'contents . There a smaller skin',
#  'Hugh . It about half full',
#  'moccasins . All new and well',
#  '. “ They my mother ’',
#  'Truly . There two suits and',
#  'She knows you the elder and',
#  'elder and must the larger .”',
#  '. “ They better to wear',
#  'a moment Hugh silent with embarrassment',
#  'embarrassment . He touched by the',
#  'the gift would to offer a',
#  '. “ I obliged to your',
#  '. “ It — kind of',
#  'the year food scarce . That',
#  '. That manomin all that remained',
#  'tiny clearing , Jean Beaupré ’',
#  'grave . Hugh surprised and horrified',
#  'see that it , in appearance',
#  '. Poles had stuck in the',
#  '. “ It the Ojibwa custom',
#  '.” “ Father not an Ojibwa',
#  'Ojibwa . He a white man',
#  'and should have buried like a',
#  '. Our father an Ojibwa by',
#  'adoption and it right they should',
#  's anger had cooling . After',
#  ', and it something to know',
#  'grave would not disturbed . In',
#  'half - brothers more than ordinarily',
#  'the bay had a favorite stopping',
#  'the river that hard to navigate',
#  ', Grand Portage not so busy',
#  '’ s supplies almost exhausted and',
#  ', nothing could spared . Anxious',
#  'of the woods to boil them',
#  '. “ It good ,” he',
#  '. “ It yours ,” the',
#  '. “ You the elder son',
#  'son . It yours .” The',
#  ', but fate against them .',
#  'Before dawn rain beating on the',
#  '. That storm the beginning of',
#  '. So they obliged to consume',
#  '. Their progress necessarily slow ,',
#  'but because they obliged to skirt',
#  'It might have thrown up on',
#  'canoe where that possible , or',
#  'for the river still high from',
#  'or rock reefs , Hugh ----',
#  '---- , Hugh learning , common',
#  '. The bar passed , but',
#  '. The current strong , and',
#  'and just ahead foaming rapids where',
#  '. “ It my mother ’',
#  'you mean this my father ’',
#  '. “ It my mother ’',
#  'skin . It from the elk',
#  'See , it just like ours',
#  'Then it may about here somewhere',
#  'here somewhere father wrecked .” “',
#  'make search ,” the brief reply',
#  'with something that not a rock',
#  'where it had dropped or thrust',
#  'found it to a ragged deerskin',
#  '. “ This Black Thunder ’',
#  'doubt this shirt his .” “',
#  '- breed lad keen witted in',
#  '“ It may ,” Hugh speculated',
#  '“ that they wrecked farther along',
#  'perhaps he had bleeding from a',
#  '.” “ Where it ?” asked',
#  ', for there no poles .',
#  '. It may he cooked but',
#  '. If anyone slain here ,”',
#  'stains . It a long time',
#  'ago that he here , I',
#  'If Black Thunder killed here ,”',
#  ', “ what done with his',
#  '. “ There the lake ,',
#  '“ Then why his blood -',
#  'Might it not that father ----',
#  '---- that father wearing Black Thunder',
#  'that the stains from his wound',
#  'and the stains in the wrong',
#  'place . They on the breast',
#  'The blood must Black Thunder ’',
#  '.” The sun going down when',
#  '. “ There evil stories of',
#  'here , it because he ----',
#  '---- because he very weary indeed',
#  'indeed . He a brave man',
#  ', yet this not such a',
#  '.” “ There evil stories of',
#  'this river flows the abode of',
#  'that lake have found the devil',
#  'So the lake called the ‘',
#  'name . It said that when',
#  'trout , it this way he',
#  'do now , not without his',
#  'if the tale true ,” the',
#  'everyone knows there devils , both',
#  'know we it not that devil',
#  'ground ? I no coward ,',
#  'afterglow , which tinting sky and',
#  'shore the canoe skirting . Not',
#  'insects might have sent by the',
#  'what appeared to part of a',
#  '. The thing indeed the shattered',
#  'pebbles . It not Jean Beaupré',
#  ', which had increasing for some',
#  '. The time past noon ,',
#  'sea would not likely to go',
#  'paddled . Luck with them and',
#  'Knowing it would some hours before',
#  'the lake would calm enough for',
#  'stay where they till morning .',
#  '. The night unusually mild for',
#  'with you ,” Hugh ’ s',
#  'hundred feet away two canoes ,',
#  'but the morning clear of fog',
#  '’ s attention attracted to the',
#  'Indeed that man too notable and',
#  '- muscled arms conspicuous as he',
#  'the time camp reached , the',
#  'the elder brother almost bursting with',
#  'curiosity . Who the huge Indian',
#  'why had Blaise so startled ,',
#  '? “ Who Ohrante ?” Hugh',
#  '. “ He more to ----',
#  '---- more to feared than the',
#  'lake himself ,” the grim reply',
#  'he would always a cripple .',
#  'him . They taking him back',
#  'law or to turned over to',
#  'justice ,— there some disagreement between',
#  'which course should followed ,— when',
#  'five . He bold to return',
#  'soon . I glad he goes',
#  'hope my mother with others ,',
#  ', unless it with two or',
#  'No , he a Mohawk ,',
#  'Company . It said his mother',
#  'said his mother an Ojibwa captive',
#  ', but Ohrante an evil Iroquois',
#  'of Iroquois hunters unwise policy ,”',
#  'year . They greedy for pelts',
#  ', will soon left without furs',
#  '.” “ That short - sighted',
#  ', and Ohrante the worst of',
#  '. His mind occupied with a',
#  '“ that it Ohrante who killed',
#  'believed it might another enemy .',
#  'And my heart troubled for my',
#  'Once when she a girl she',
#  'a girl she a captive among',
#  'Sioux . To captured by Ohrante',
#  'by Ohrante would even worse ,',
#  'and now there no Jean Beaupré',
#  'river . She sad because she',
#  'because she had taken from her',
#  'them . She very young then',
#  'beautiful . She not old even',
#  ', and she still beautiful ,”',
#  'Was it to wondered at that',
#  'his mother and anxious about her',
#  '. “ Ohrante not coming from',
#  ', and there no women in',
#  'Surely your mother among friends by',
#  '.” “ That true ,” Blaise',
#  'war .” He silent for a',
#  ', “ There but one thing',
#  'our breakfast and away then .”',
#  'then .” Blaise untying the package',
#  '“ The Iroquois not yet far',
#  'eat .” Hugh hungry , but',
#  'the two lads well on their',
#  'as a lawyer a failure ,',
#  '137 ] He exposed to Jain',
#  'mother who , in contact with',
#  'views of truth partial , a',
#  ', his outlook parochial and he',
#  'felt that Gandhi influenced by the',
#  'a Swaminarayan household attracted to Gandhi',
#  's ethical thinking heavily influenced by',
#  'Absolute Reality can comprehended only relatively',
#  'of the rulers learned as a',
#  'a national audience drawn from Ahmedabad',
#  '. Accordingly they even more vigilant',
#  'There proved to about a dozen',
#  'yearling moose had killed the day',
#  'muskets . They from the deep',
#  'heard that it through his great',
#  'divulging that he the son of',
#  'outlaw had first seen since his',
#  '. “ I told he ----',
#  '---- told he here at this',
#  '. “ That February or March',
#  '? And it late in March',
#  '’ s , hot against his',
#  ', the boys off shortly after',
#  'as the sun coming up ,',
#  'her sail , a ship .',
#  'thought she must at least as',
#  'sail . What a ship doing',
#  'Yankee traders who now invading the',
#  'knew he had in United States',
#  'shrank . She no longer as',
#  '_Otter_ . She much smaller .',
#  'smaller . She not a ship',
#  'sail . There something about the',
#  'than it really . The sailboat',
#  '. The sailboat coming slowly in',
#  'they saw it a small ,',
#  'ends . It well loaded and',
#  'cap , who steering , replied',
#  ', that they from the Fond',
#  '. Blaise had even more amazed',
#  'lake must have playing tricks with',
#  'aboard that bateau using magic .',
#  'not think there anything magical about',
#  'the lad had convinced . Several',
#  '. The journey becoming wearisome indeed',
#  'store of food scant . The',
#  'but their luck poor . Seldom',
#  'poor . Seldom they able to',
#  'might almost have whole brother to',
#  'a camper he nearly the Indian',
#  'prided himself on a better cook',
#  'but the name used by the',
#  'day the name no longer applied',
#  'itself , but restricted to the',
#  'river . There no town of',
#  '. That line the long ,',
#  ', sand point by no means',
#  'much of it covered more or',
#  'The two lads weary , discouraged',
#  '. The sun setting . Unless',
#  'the lines had poor throughout most',
#  'When the meal over , nothing',
#  'soon as they rolled in their',
#  ', but it not the annoying',
#  'boat must have battered to pieces',
#  'discovering the cache to find the',
#  'chance seems to gone .” “',
#  '.” “ There still one other',
#  '.” “ You right ,” ----',
#  '---- right ,” Hugh ’ s',
#  'may once have there or near',
#  '“ The bateau perhaps driven on',
#  ', if it Ohrante who killed',
#  'told you he wrecked in a',
#  'and where he attacked we do',
#  'it must have after he cached',
#  'hurt , he beyond replying .”',
#  '.” Both boys silent a moment',
#  'midstream the current strong , but',
#  'of bark lodges passed , where',
#  'several posts that still maintained in',
#  'provisions . Blaise not known to',
#  'Brought up to truthful and straightforward',
#  'he and Hugh on their way',
#  'of salt pork all the clerk',
#  'the clerk could persuaded to part',
#  '. As they leaving he gave',
#  'band . They reported to ----',
#  '---- reported to lingering along the',
#  'shore and they a bad lot',
#  'He used to a hunter for',
#  'white man and an outcast now',
#  '. The rascal called Ohrante .',
#  '. The brothers glad to get',
#  '. The village unkempt , and',
#  'smelling . It evident that most',
#  'of the squaws just recovering from',
#  '. “ They ruining the Ojibwa',
#  'now the custom started , but',
#  '. Always he a friend to',
#  ', and he a good son',
#  'him . He a strong man',
#  'well . Departure delayed by rain',
#  'stream mouth and away again at',
#  '. There would no moon till',
#  '. The wind light , merely',
#  'the bow , still steadily plying',
#  'if he feared overheard even at',
#  '. “ It best to avoid',
#  '. A fire blazing in an',
#  'shouts and yells borne across the',
#  'of the ordinary going on .',
#  'on . That no mere cooking',
#  'the black figures capering and yelling',
#  'the fire burned near the Devil',
#  '. But it some miles away',
#  'and louder , from the throats',
#  '. Blaise had considering his whereabouts',
#  'ground he has over , he',
#  'the fire burned the rocky end',
#  'sound that could distinguished from the',
#  'to the tree a man ,',
#  'six other figures leaping and yelling',
#  'the horrid scene plain enough .',
#  'unlucky Indian captive ---- tortured to',
#  'Indian captive ---- tortured to death',
#  'death . It not the tortured',
#  'cautiously . They beyond the fire',
#  'shore and island narrow . Until',
#  'blazing pile itself hidden from view',
#  'exhaustion though they , they paddled',
#  'Not until they several miles away',
#  'HUNGRY PORCUPINE Hugh alone in a',
#  'storm wind , an enormous black',
#  '. The boy trying to turn',
#  'realized that Blaise not with him',
#  'canoe , where they ? He',
#  'where they had tossed , on',
#  'the packages had dropped . The',
#  'Blaise , who plunging in to',
#  'just as it floating away .',
#  'The maple sugar partly dissolved .',
#  'though the wrapping supposed to ----',
#  '---- supposed to water - proof',
#  '- proof , soaked , and',
#  'other things , so wet it',
#  'would have to dried and oiled',
#  'before it could used . Blaise',
#  ', and it safe and dry',
#  'sound , had so tired and',
#  'him . It not until a',
#  'had rescued had carried beyond the',
#  'clothes might have cast up in',
#  'shallow cove , not long .',
#  ', the sun just coming up',
#  '. The wind a little east',
#  'where the boys camped , but',
#  'The little cove open and unprotected',
#  'such a blow out of the',
#  'which direction Ohrante bound ,” Hugh',
#  '. “ He probably going down',
#  'him last night a great risk',
#  'their eyes would blinded by the',
#  'we must still cautious and make',
#  'this gale to seen ,” Hugh',
#  'them . Caution never wasted ,',
#  'food . They far enough from',
#  'shot that had saved , Blaise',
#  ', where there much undergrowth ,',
#  'much undergrowth , difficult and he',
#  'him , he not much annoyed',
#  ', his luck not good .',
#  'nor rabbit meat at its best',
#  ', but it at least better',
#  '’ s nostrils made up of',
#  'the waves had going down .',
#  'though the lake by no means',
#  'and Blaise not in such a',
#  'morning . They so anxious to',
#  'while the afterglow still reflected in',
#  'not need to told to look',
#  'in the bark too conspicuous .',
#  '. “ It the devil in',
#  'see .” Blaise right . When',
#  'When the canoe lifted , the',
#  'of salt pork gone , taken',
#  '. Nothing else missing . “',
#  'or the pork all he could',
#  'of the pork bad ,” Blaise',
#  'in the canoe bad also ,',
#  'of the pork indeed serious .',
#  'day before had eaten , and',
#  ', he had wary enough to',
#  ', had not lost when the',
#  'Then the canoe left bottom side',
#  'thoroughness , they determined to go',
#  '“ Can this the boat ,',
#  '. “ It not here on',
#  'Yet it may part of the',
#  '. “ That possible . If',
#  'know whether it the right one',
#  'for the mast painted with vermilion',
#  'it in black our father ’',
#  'Twice the sign there , once',
#  'mast .” Hugh staring at his',
#  '. “ That it ,” Hugh',
#  'No , I wide awake ,',
#  ', but it a long way',
#  '. If it so badly damaged',
#  'When that boat carried across to',
#  'and Black Thunder still in it',
#  'did . They borne away and',
#  'the younger lad not so easily',
#  'Minong if he wrecked there ?',
#  'and the bateau still there .”',
#  'know his wound not received in',
#  'yourself say it a knife wound',
#  'but the bateau beyond repair .',
#  '. Here they set upon and',
#  'and Black Thunder killed and father',
#  '. “ Why they away down',
#  'them ?” Hugh aware of the',
#  'that the furs not far from',
#  '. I cannot mistaken .” “',
#  'they came to so far down',
#  'if the packet valuable , why',
#  '’ s body very weak and',
#  'the way it marked , but',
#  '.” Both lads silent for several',
#  'Blaise , there just two things',
#  'packet . I for the latter',
#  'paddles .” It plain that Hugh',
#  'Hitherto he had content to let',
#  'but now he asserting his elder',
#  '- breed lad proud . He',
#  'proud . He not going to',
#  'weeks they might delayed before they',
#  'at least could bought . From',
#  'Indians always to found near the',
#  'new moccasins might obtained . Considering',
#  'gaff would have a risk at',
#  'wildly flapping , raised from the',
#  'most of them taken in nets',
#  ', but it not good to',
#  '. “ That not the _Otter_',
#  'No , it not one of',
#  '’ s money exhausted by the',
#  'brother could not persuaded to divulge',
#  ', when they returning from the',
#  'when the boys leaving the Bay',
#  's post and about to leave',
#  'leave . They going to portage',
#  'small bateau which drawn up on',
#  'all his money gone . Blaise',
#  'Ojibwa . He a Scotch half',
#  'gun , which better than his',
#  ', but he eager to secure',
#  'which he had using as a',
#  'of the day spent in making',
#  '. The boat pointed at both',
#  'the trappers had content to steer',
#  'sail . It a satisfaction to',
#  'as he had leader . The',
#  'mode of travel a pleasant change',
#  'course would have to cross directly',
#  'of Isle Royale but imperfectly understood',
#  '. It had visited by scarcely',
#  'white men and avoided by the',
#  'sail the sky blue overhead ,',
#  ', but there still haze enough',
#  'distance . It not strange that',
#  'than it really . From its',
#  'the island must from some point',
#  'Bay . He aware of the',
#  'that curve would a loss of',
#  'bay . It from one of',
#  '. So anxious the two to',
#  'comradeship . Speech unnecessary between them',
#  'advanced , Blaise not so sure',
#  'sure that fortune favoring the venture',
#  'until the water broken by the',
#  'only . There scarcely enough pressure',
#  'rate we shall a week in',
#  'this heavy bateau hard work ,”',
#  'Before the sun overhead , there',
#  ', there will no wind at',
#  'noon the sail hanging loose and',
#  'cloudless sky , without a wrinkle',
#  'wrinkle . It not often really',
#  ', clumsy boat slow , hot',
#  'go . There the Isle Royale',
#  'if it had sliced off with',
#  'it seemed to , but curiously',
#  '. “ There something wrong ,”',
#  '“ We must off our course',
#  'course . That not Isle Royale',
#  'saw . Where we , Blaise',
#  '? Can that part of the',
#  '?” “ It not the mainland',
#  '“ It must some part of',
#  ', the island changing before our',
#  ', where it high a moment',
#  '!” “ It some enchanted land',
#  '. “ It a land of',
#  'moment Hugh too inclined to believe',
#  'and his brother the victims of',
#  'very boat he now in ,',
#  ', when he on his way',
#  '. “ It the mirage .',
#  'that the mirage caused by the',
#  'appear where there no land or',
#  'images of islands seen upside down',
#  'line . It all very strange',
#  ', but there no enchantment about',
#  'any rate Blaise too proud to',
#  'not seem to afraid of .',
#  'efforts . Progress very slow .',
#  '. White clouds gathering in the',
#  '. Both boys growing anxious .',
#  'moving though they , threatened storm',
#  ', a ripple spreading over the',
#  '. A breeze coming up from',
#  'the setting sun breaking through the',
#  'orange . He glad to see',
#  'assurance that he keeping the course',
#  'sail could not made to beat',
#  '’ s course a little north',
#  'wind and yet assured of not',
#  'he took to the end of',
#  '. That land still very far',
#  'shimmering path , a pleasant change',
#  'The day had a long one',
#  'disaster . They approaching land now',
#  'and projecting rocks not difficult .',
#  '. Sunken reefs harder to discern',
#  'Hugh would have glad to camp',
#  'bordering ones , passed before reaching',
#  'the _Otter_ had obliged to go',
#  '. No damage done , however',
#  '. The bateau now headed for',
#  'thought that must the towering ,',
#  'land there tonight out of the',
#  'wet planking they asleep immediately .',
#  'ROCK The brothers in the habit',
#  'but it had nearly dawn when',
#  'until the sun well started on',
#  's first glance towards the land',
#  'water . There no mistaking that',
#  'above . It the same shore',
#  '. “ That the place we',
#  'can ’ t more than a',
#  'rocks ? It a little cove',
#  'to the left the crack where',
#  ', when we leaving , I',
#  'now the birches in leaf ,',
#  'm sure it the same .',
#  'same . There two little coves',
#  'and the cliff a little farther',
#  ', but I hungry ,” he',
#  'if his purpose to dash the',
#  '. Now he obliged to act',
#  'a short point the bit of',
#  'the pebbles had bare limbed .',
#  'gone , they all in full',
#  'the mountain ashes almost ready to',
#  'the ninebark bushes covered with masses',
#  '’ s mind on the wreck',
#  'of the crack almost vertical ,',
#  '“ It will difficult ,” Blaise',
#  '“ The wind not going down',
#  'down , it coming up ,”',
#  '. His weight thrown upon a',
#  'root seemed to firmly anchored ,',
#  '. The bateau more than half',
#  'him . He not hurt ,',
#  'right , but careful ,” the',
#  'boat . It the vermilion painted',
#  '. “ It our father ’',
#  'times . This his bateau ,',
#  'but whether it wrecked here or',
#  'I believe it wrecked here ,”',
#  'how the end splintered . This',
#  '. This boat driven upon these',
#  '. But it empty . We',
#  'that might have intended as a',
#  'as a guide a groove across',
#  'short lines had cut diagonally to',
#  ', if it on the island',
#  'island , must sought that way',
#  'of the boat firmly lodged among',
#  'which it had driven . Over',
#  'himself that there no furs there',
#  'left hand wall almost perpendicular ,',
#  'those blocks Hugh standing . He',
#  '. “ There no furs here',
#  '. Hugh had almost certain he',
#  'cache . He keenly disappointed .',
#  'Yes . It a small place',
#  '.” “ There no furs there',
#  '. “ You not the first',
#  'then . What the meaning of',
#  ...]

# %%
y
# Out:
# ['was',
#  'were',
#  'was',
#  'been',
#  'was',
#  'be',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'are',
#  'is',
#  'is',
#  'was',
#  'was',
#  'was',
#  'was',
#  'is',
#  'was',
#  'been',
#  'been',
#  'been',
#  'been',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'is',
#  'was',
#  'was',
#  'was',
#  'be',
#  'were',
#  'are',
#  'am',
#  'be',
#  'be',
#  'be',
#  'was',
#  'been',
#  'been',
#  'be',
#  'be',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'being',
#  'was',
#  'been',
#  'be',
#  'been',
#  'was',
#  'be',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'am',
#  'was',
#  'are',
#  'is',
#  'is',
#  'is',
#  'am',
#  'is',
#  'were',
#  'are',
#  'is',
#  'be',
#  'is',
#  'was',
#  'be',
#  'was',
#  'was',
#  'were',
#  'was',
#  'were',
#  'were',
#  'was',
#  'were',
#  'was',
#  'been',
#  'was',
#  'being',
#  'be',
#  'was',
#  'been',
#  'was',
#  'are',
#  'was',
#  'been',
#  'was',
#  'been',
#  'be',
#  'were',
#  'be',
#  'was',
#  'be',
#  'be',
#  'was',
#  'was',
#  'be',
#  'were',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'be',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'was',
#  'being',
#  'been',
#  'was',
#  'was',
#  'be',
#  'been',
#  'been',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'were',
#  'was',
#  'been',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'were',
#  'being',
#  'was',
#  'was',
#  'was',
#  'been',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'were',
#  'was',
#  'is',
#  'are',
#  'was',
#  'is',
#  'is',
#  'be',
#  'are',
#  'are',
#  'is',
#  'are',
#  'are',
#  'is',
#  'be',
#  'be',
#  'is',
#  'were',
#  'been',
#  'is',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'be',
#  'was',
#  'being',
#  'was',
#  'been',
#  'were',
#  'was',
#  'were',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'is',
#  'was',
#  'was',
#  'been',
#  'is',
#  'been',
#  'is',
#  'is',
#  'is',
#  'are',
#  'been',
#  'been',
#  'was',
#  'be',
#  'was',
#  'were',
#  'was',
#  'was',
#  'were',
#  'is',
#  'been',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'been',
#  'was',
#  'were',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'were',
#  'were',
#  'been',
#  'are',
#  'is',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'been',
#  'was',
#  'been',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'been',
#  'was',
#  'been',
#  'was',
#  'were',
#  'was',
#  'was',
#  'be',
#  'be',
#  'was',
#  'been',
#  'be',
#  'are',
#  'is',
#  'is',
#  'was',
#  'is',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'been',
#  'was',
#  'is',
#  'was',
#  'was',
#  'been',
#  'been',
#  'was',
#  'are',
#  'was',
#  'were',
#  'was',
#  'be',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'been',
#  'was',
#  'were',
#  'be',
#  'been',
#  'was',
#  'is',
#  'were',
#  'been',
#  'was',
#  'was',
#  'be',
#  'been',
#  'be',
#  'is',
#  'was',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'were',
#  'be',
#  'be',
#  'are',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'were',
#  'was',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'be',
#  'were',
#  'was',
#  'were',
#  'be',
#  'be',
#  'was',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'been',
#  'was',
#  'been',
#  'is',
#  'are',
#  'been',
#  'is',
#  'been',
#  'was',
#  'was',
#  'were',
#  'are',
#  'are',
#  'are',
#  'be',
#  'are',
#  'was',
#  'was',
#  'be',
#  'am',
#  'was',
#  'is',
#  'is',
#  'was',
#  'was',
#  'was',
#  'been',
#  'is',
#  'was',
#  'was',
#  'been',
#  'was',
#  'was',
#  'been',
#  'was',
#  'be',
#  'were',
#  'been',
#  'is',
#  'was',
#  'were',
#  'be',
#  'was',
#  'is',
#  'is',
#  'are',
#  'is',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'were',
#  'been',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'were',
#  'is',
#  'was',
#  'is',
#  'is',
#  'is',
#  'be',
#  'was',
#  'was',
#  'was',
#  'been',
#  'be',
#  'is',
#  'was',
#  'was',
#  'be',
#  'were',
#  'been',
#  'was',
#  'are',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'is',
#  'was',
#  'be',
#  'was',
#  'are',
#  'are',
#  'are',
#  'be',
#  'was',
#  'are',
#  'was',
#  'was',
#  'was',
#  'is',
#  'are',
#  'is',
#  'been',
#  'is',
#  'is',
#  'is',
#  'was',
#  'is',
#  'are',
#  'was',
#  'am',
#  'was',
#  'was',
#  'been',
#  'be',
#  'was',
#  'was',
#  'been',
#  'was',
#  'be',
#  'was',
#  'be',
#  'be',
#  'were',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'been',
#  'is',
#  'is',
#  'be',
#  'was',
#  'be',
#  'were',
#  'be',
#  'was',
#  'be',
#  'is',
#  'am',
#  'is',
#  'be',
#  'is',
#  'is',
#  'was',
#  'is',
#  'is',
#  'are',
#  'be',
#  'is',
#  'is',
#  'was',
#  'was',
#  'be',
#  'is',
#  'was',
#  'was',
#  'be',
#  'be',
#  'is',
#  'was',
#  'been',
#  'was',
#  'is',
#  'is',
#  'be',
#  'was',
#  'is',
#  'are',
#  'is',
#  'is',
#  'was',
#  'is',
#  'be',
#  'was',
#  'is',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'are',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'were',
#  'were',
#  'were',
#  'be',
#  'been',
#  'were',
#  'was',
#  'was',
#  'been',
#  'was',
#  'was',
#  'is',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'be',
#  'was',
#  'were',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'been',
#  'been',
#  'was',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'were',
#  'been',
#  'was',
#  'being',
#  'was',
#  'is',
#  'is',
#  'was',
#  'was',
#  'was',
#  'being',
#  'were',
#  'was',
#  'been',
#  'was',
#  'were',
#  'was',
#  'been',
#  'was',
#  'be',
#  'is',
#  'are',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'been',
#  'was',
#  'were',
#  'was',
#  'was',
#  'were',
#  'was',
#  'be',
#  'were',
#  'were',
#  'be',
#  'were',
#  'are',
#  'be',
#  'are',
#  'be',
#  'is',
#  'is',
#  'were',
#  'was',
#  'was',
#  'were',
#  'are',
#  'is',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'be',
#  'was',
#  'was',
#  'being',
#  'is',
#  'was',
#  'were',
#  'was',
#  'was',
#  'were',
#  'been',
#  'was',
#  'were',
#  'been',
#  'been',
#  'was',
#  'be',
#  'was',
#  'were',
#  'was',
#  'was',
#  'being',
#  'was',
#  'were',
#  'was',
#  'was',
#  'were',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'been',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'was',
#  'be',
#  'be',
#  'was',
#  'been',
#  'was',
#  'been',
#  'been',
#  'was',
#  'was',
#  'was',
#  'were',
#  'being',
#  'was',
#  'is',
#  'is',
#  'was',
#  'be',
#  'be',
#  'be',
#  'is',
#  'were',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'been',
#  'was',
#  'been',
#  'were',
#  'was',
#  'be',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'is',
#  'is',
#  'was',
#  'been',
#  'been',
#  'been',
#  'was',
#  'were',
#  'be',
#  'was',
#  'be',
#  'is',
#  'was',
#  'is',
#  'is',
#  'is',
#  'was',
#  'is',
#  'was',
#  'was',
#  'was',
#  'was',
#  'were',
#  'were',
#  'was',
#  'was',
#  'is',
#  'was',
#  'was',
#  'was',
#  'were',
#  'was',
#  'were',
#  'was',
#  'were',
#  'be',
#  'be',
#  'is',
#  'was',
#  'was',
#  'were',
#  'are',
#  'am',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'be',
#  'be',
#  'be',
#  'be',
#  'been',
#  'was',
#  'were',
#  'is',
#  'is',
#  'is',
#  'was',
#  'be',
#  'were',
#  'were',
#  'were',
#  'were',
#  'was',
#  'was',
#  'was',
#  'is',
#  'was',
#  'been',
#  'was',
#  'was',
#  'been',
#  'was',
#  'been',
#  'was',
#  'been',
#  'was',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'was',
#  'be',
#  'was',
#  'were',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'be',
#  'is',
#  'is',
#  'be',
#  'was',
#  'was',
#  'is',
#  'was',
#  'is',
#  'been',
#  'be',
#  'is',
#  'be',
#  'is',
#  'are',
#  'be',
#  'is',
#  'be',
#  'is',
#  'was',
#  'is',
#  'is',
#  'was',
#  'were',
#  'was',
#  'was',
#  'is',
#  'is',
#  'is',
#  'are',
#  'is',
#  'is',
#  'was',
#  'be',
#  'was',
#  'were',
#  'were',
#  'were',
#  'was',
#  'was',
#  'were',
#  'was',
#  'was',
#  'be',
#  'was',
#  'be',
#  'be',
#  'was',
#  'was',
#  'been',
#  'were',
#  'was',
#  'were',
#  'been',
#  'were',
#  'been',
#  'was',
#  'was',
#  'be',
#  'was',
#  'were',
#  'were',
#  'been',
#  'was',
#  'was',
#  'was',
#  'was',
#  'is',
#  'be',
#  'is',
#  'is',
#  'were',
#  'are',
#  'is',
#  'are',
#  'is',
#  'am',
#  'were',
#  'was',
#  'was',
#  'been',
#  'were',
#  'were',
#  'were',
#  'was',
#  'were',
#  'be',
#  'is',
#  'is',
#  'was',
#  'be',
#  'was',
#  'was',
#  'be',
#  'was',
#  'is',
#  'was',
#  'was',
#  'was',
#  'is',
#  'was',
#  'is',
#  'been',
#  'was',
#  'been',
#  'is',
#  'be',
#  'was',
#  'been',
#  'were',
#  'was',
#  'was',
#  'are',
#  'been',
#  'was',
#  'is',
#  'are',
#  'were',
#  'is',
#  ...]

# %%
l = LabelEncoder()
y = l.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
vectorizer = CountVectorizer()
classifier = PassiveAggressiveClassifier()
pipe = make_pipeline(vectorizer, classifier)
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.passive_aggressive.PassiveAggressiveClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
sample = str(input("Enter the text:\n"))
sample = wordpunct_tokenize(sample)
sample = create_windows(sample)
prediction = l.inverse_transform(pipe.predict(sample))
print("\n Predictions:")
with open('output.txt', 'w') as f:
    f.write('\n'.join(prediction))
    print('\n'.join(prediction))
# Out:
# Enter the text:
# When the modern Olympics began in 1896, the initiators and organizers ---- looking for a great popularizing event, recalling the ancient glory of Greece. The idea of a marathon race came from Michel Breal, who wanted the event to feature in the first modern Olympic Games in 1896 in Athens. This idea was heavily supported by Pierre de Coubertin, the founder of the modern Olympics, as well as by the Greeks. The Greeks staged a selection race for the Olympic marathon on 10 March 1896 that ---- won by Charilaos Vasilakos in 3 hours and 18 minutes (with the future winner of the introductory Olympic Games marathon coming in fifth). The winner of the first Olympic Marathon, on 10 April 1896 (a male-only race), was Spyridon "Spyros" Louis, a Greek water-carrier, in 2 hours 58 minutes and 50 seconds. The women's marathon ---- introduced at the 1984 Summer Olympics (Los Angeles, USA) and ---- won by Joan Benoit of the United States with a time of 2 hours 24 minutes and 52 seconds. Since the modern games were founded, it has become a tradition for the men's Olympic marathon to be the last event of the athletics calendar, with a finish inside the Olympic stadium, often within hours of, or even incorporated into, the closing ceremonies. The marathon of the 2004 Summer Olympics revived the traditional route from Marathon to Athens, ending at Panathinaiko Stadium, the venue for the 1896 Summer Olympics. Since the modern games ---- founded, it has become a tradition for the men's Olympic marathon to be the last event of the athletics calendar, with a finish inside the Olympic stadium, often within hours of, or even incorporated into, the closing ceremonies. The marathon of the 2004 Summer Olympics revived the traditional route from Marathon to Athens, ending at Panathinaiko Stadium, the venue for the 1896 Summer Olympics. The Olympic men's record ---- 2:06:32.
#
#  Predictions:
# was
# was
# was
# was
# was
# been
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
